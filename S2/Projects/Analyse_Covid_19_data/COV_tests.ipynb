# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('Data/covid_19_data.csv')
data.columns
# Out:
# Index(['SNo', 'ObservationDate', 'Province/State', 'Country/Region',
#        'Last Update', 'Confirmed', 'Deaths', 'Recovered'],
#       dtype='object')

# %%
data = data.sort_values(by=['Province/State', 'Country/Region'])
data = data.reset_index(drop=True)

# %%
data
# Out:
#          SNo ObservationDate Province/State                  Country/Region  \
# 0       2745      02/28/2020   Montreal, QC                          Canada
# 1       2864      02/29/2020   Montreal, QC                          Canada
# 2       2994      03/01/2020   Montreal, QC                          Canada
# 3       3128      03/02/2020   Montreal, QC                          Canada
# 4       3279      03/03/2020   Montreal, QC                          Canada
# ...      ...             ...            ...                             ...
# 306424  5253      03/12/2020            NaN  occupied Palestinian territory
# 306425  5736      03/14/2020            NaN  occupied Palestinian territory
# 306426  5996      03/15/2020            NaN  occupied Palestinian territory
# 306427  6270      03/16/2020            NaN  occupied Palestinian territory
# 306428  6548      03/17/2020            NaN  occupied Palestinian territory
#
# ...

# %%
china_data = data[data['Country/Region'] == 'Mainland China']

# %%
Hubei_data = china_data[china_data['Province/State'] == 'Hubei']

# %%
pwd
# Out:
# '/home/guler/Teaching/Python/Python_Initiations/GitHub/python-teaching/S2/Projects/Analyse_Covid_19_data'

# %%
# %matplotlib inline
plt.plot(Hubei_data.Deaths / Hubei_data.Confirmed)
plt.plot(Hubei_data.Recovered / Hubei_data.Confirmed)

# %%
data_rec = pd.read_csv('Data/time_series_covid_19_recovered.csv')
data_rec.columns
# Out:
# Index(['Province/State', 'Country/Region', 'Lat', 'Long', '1/22/20', '1/23/20',
#        '1/24/20', '1/25/20', '1/26/20', '1/27/20',
#        ...
#        '5/20/21', '5/21/21', '5/22/21', '5/23/21', '5/24/21', '5/25/21',
#        '5/26/21', '5/27/21', '5/28/21', '5/29/21'],
#       dtype='object', length=498)

# %%
data_rec
# Out:
#     Province/State      Country/Region        Lat        Long  1/22/20  \
# 0              NaN         Afghanistan  33.939110   67.709953        0
# 1              NaN             Albania  41.153300   20.168300        0
# 2              NaN             Algeria  28.033900    1.659600        0
# 3              NaN             Andorra  42.506300    1.521800        0
# 4              NaN              Angola -11.202700   17.873900        0
# ..             ...                 ...        ...         ...      ...
# 256            NaN             Vietnam  14.058324  108.277199        0
# 257            NaN  West Bank and Gaza  31.952200   35.233200        0
# 258            NaN               Yemen  15.552727   48.516388        0
# 259            NaN              Zambia -13.133897   27.849332        0
# 260            NaN            Zimbabwe -19.015438   29.154857        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  5/20/21  5/21/21  \
# ...

# %%
data_rec[data_rec['Country/Region'] == 'France']
# Out:
#                 Province/State Country/Region        Lat        Long  1/22/20  \
# 104              French Guiana         France   3.933900  -53.125800        0
# 105           French Polynesia         France -17.679700  149.406800        0
# 106                 Guadeloupe         France  16.265000  -61.551000        0
# 107                 Martinique         France  14.641500  -61.024200        0
# 108                    Mayotte         France -12.827500   45.166244        0
# 109              New Caledonia         France -20.904305  165.618042        0
# 110                    Reunion         France -21.115100   55.536400        0
# 111           Saint Barthelemy         France  17.900000  -62.833300        0
# 112  Saint Pierre and Miquelon         France  46.885200  -56.315900        0
# 113                  St Martin         France  18.070800  -63.050100        0
# 114          Wallis and Futuna         France -14.293800 -178.116500        0
# ...

# %%
data_conf = data_rec.columns[4:]

# %% [markdown]
# La fonction pandas.melt() remodèle ou transforme un DataFrame existant. Il change l’orientation du DataFrame d’un format large à un format long.

# %%
data_rec_melted = data_rec.melt(id_vars=['Province/State','Country/Region', 'Lat','Long'], value_vars=data_conf, var_name='Date', value_name='Confirmed')

# %%
data_rec_melted
# Out:
#        Province/State      Country/Region        Lat        Long     Date  \
# 0                 NaN         Afghanistan  33.939110   67.709953  1/22/20
# 1                 NaN             Albania  41.153300   20.168300  1/22/20
# 2                 NaN             Algeria  28.033900    1.659600  1/22/20
# 3                 NaN             Andorra  42.506300    1.521800  1/22/20
# 4                 NaN              Angola -11.202700   17.873900  1/22/20
# ...               ...                 ...        ...         ...      ...
# 128929            NaN             Vietnam  14.058324  108.277199  5/29/21
# 128930            NaN  West Bank and Gaza  31.952200   35.233200  5/29/21
# 128931            NaN               Yemen  15.552727   48.516388  5/29/21
# 128932            NaN              Zambia -13.133897   27.849332  5/29/21
# 128933            NaN            Zimbabwe -19.015438   29.154857  5/29/21
#
#         Confirmed
# 0               0
# 1               0
# 2               0
# ...

# %%
fr_melt = data_rec_melted[data_rec_melted['Country/Region'] == 'France']

# %%
fr_melt.to_csv('Fr.csv')

# %%
fr_melt
# Out:
#                    Province/State Country/Region      Lat        Long  \
# 104                 French Guiana         France   3.9339  -53.125800
# 105              French Polynesia         France -17.6797  149.406800
# 106                    Guadeloupe         France  16.2650  -61.551000
# 107                    Martinique         France  14.6415  -61.024200
# 108                       Mayotte         France -12.8275   45.166244
# ...                           ...            ...      ...         ...
# 128784           Saint Barthelemy         France  17.9000  -62.833300
# 128785  Saint Pierre and Miquelon         France  46.8852  -56.315900
# 128786                  St Martin         France  18.0708  -63.050100
# 128787          Wallis and Futuna         France -14.2938 -178.116500
# 128788                        NaN         France  46.2276    2.213700
#
#            Date  Confirmed
# 104     1/22/20          0
# 105     1/22/20          0
# 106     1/22/20          0
# ...

# %%
fr0 = fr_melt[fr_melt.isnull().any(1)]

# %%
fr0
# Out:
#        Province/State Country/Region      Lat    Long     Date  Confirmed
# 115               NaN         France  46.2276  2.2137  1/22/20          0
# 376               NaN         France  46.2276  2.2137  1/23/20          0
# 637               NaN         France  46.2276  2.2137  1/24/20          0
# 898               NaN         France  46.2276  2.2137  1/25/20          0
# 1159              NaN         France  46.2276  2.2137  1/26/20          0
# ...               ...            ...      ...     ...      ...        ...
# 127744            NaN         France  46.2276  2.2137  5/25/21     327636
# 128005            NaN         France  46.2276  2.2137  5/26/21     328943
# 128266            NaN         France  46.2276  2.2137  5/27/21     329920
# 128527            NaN         France  46.2276  2.2137  5/28/21     331006
# 128788            NaN         France  46.2276  2.2137  5/29/21     331686
#
# [494 rows x 6 columns]

# %%
plt.plot(fr0.Confirmed)
