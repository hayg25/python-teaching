# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('covid_19_data.csv')
df1 = pd.read_csv('covid_data_full.csv')

# %%
df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 306429 entries, 0 to 306428
# Data columns (total 8 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   SNo              306429 non-null  int64
#  1   ObservationDate  306429 non-null  object
#  2   Province/State   228329 non-null  object
#  3   Country/Region   306429 non-null  object
#  4   Last Update      306429 non-null  object
#  5   Confirmed        306429 non-null  float64
#  6   Deaths           306429 non-null  float64
#  7   Recovered        306429 non-null  float64
# dtypes: float64(3), int64(1), object(4)
# memory usage: 18.7+ MB
#            SNo ObservationDate     Province/State  Country/Region  \
# 0            1      01/22/2020              Anhui  Mainland China
# 1            2      01/22/2020            Beijing  Mainland China
# 2            3      01/22/2020          Chongqing  Mainland China
# ...

# %%
df_fr = df[df['Country/Region'] == 'France']
df_ch = df[df['Country/Region'] == 'Mainland China']

# %%
plt.plot(df_ch['Confirmed'])
plt.plot(df_ch['Deaths'])

# %%
df.ObservationDate
# Out:
# 0         01/22/2020
# 1         01/22/2020
# 2         01/22/2020
# 3         01/22/2020
# 4         01/22/2020
#              ...
# 306424    05/29/2021
# 306425    05/29/2021
# 306426    05/29/2021
# 306427    05/29/2021
# 306428    05/29/2021
# Name: ObservationDate, Length: 306429, dtype: object

# %%
iso = df1['iso_code']

# %%
df1_fr = df1[df1['location'] == 'France'].reset_index()
df1_ge = df1[df1['location'] == 'Germany'].reset_index()
df1_it = df1[df1['location'] == 'Italy'].reset_index()
df1_ch = df1[df1['location'] == 'China'].reset_index()

# %%
df1.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
# ...

# %%
# %matplotlib widget
debut = 180
fin = 250
plt.plot(df1_fr['new_cases_smoothed'][debut:fin])
plt.plot(df1_ch['new_cases_smoothed'][debut:fin])
plt.plot(df1_it['new_cases_smoothed'][debut:fin])
plt.plot(df1_ge['new_cases_smoothed'][debut:fin])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib inline
plt.plot(df1_ge['new_cases_smoothed'][debut:fin] / df1_fr['new_cases_smoothed'][debut:fin] )
plt.plot(df1_it['new_cases_smoothed'][debut:fin] / df1_fr['new_cases_smoothed'][debut:fin] )

# %%
# %matplotlib inline
plt.plot(df1_ge['new_cases'][debut:fin] / df1_fr['new_cases'][debut:fin] )
plt.plot(df1_it['new_cases'][debut:fin] / df1_fr['new_cases'][debut:fin] )

# %%
# %matplotlib widget
debut = 0
fin = 10000
plt.plot(df1_fr['new_deaths_smoothed'][debut:fin] / df1_fr['new_cases_smoothed'][debut:fin])
plt.plot(df1_ge['new_deaths_smoothed'][debut:fin] / df1_ge['new_cases_smoothed'][debut:fin])
plt.plot(df1_it['new_deaths_smoothed'][debut:fin] / df1_it['new_cases_smoothed'][debut:fin])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
df1.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
# ...

# %%
df1_fr['date']
# Out:
# 0      2020-01-24
# 1      2020-01-25
# 2      2020-01-26
# 3      2020-01-27
# 4      2020-01-28
#           ...
# 879    2022-06-21
# 880    2022-06-22
# 881    2022-06-23
# 882    2022-06-24
# 883    2022-06-25
# Name: date, Length: 884, dtype: object

# %%
import matplotlib
# %matplotlib widget
ax = plt.gca()
plt.plot(df1_fr['date'], df1_fr['reproduction_rate'])
plt.plot(df1_it['date'], df1_it['reproduction_rate'])
plt.plot(df1_ge['date'], df1_ge['reproduction_rate'])
ax.xaxis.set_minor_locator(matplotlib.dates.MonthLocator([1, 7]))
ax.xaxis.set_minor_formatter(matplotlib.dates.DateFormatter('%b'))
ax.xaxis.set_major_locator(matplotlib.dates.YearLocator())
ax.xaxis.set_major_formatter(matplotlib.dates.DateFormatter('%Y'))
#ax.tick_params(pad=20)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
loc_all = df1['location']
len(loc_all)
# Out:
# 196774

# %%
loc = df1['location'].drop_duplicates()
cont = df1['continent'].drop_duplicates()

# %%
df1_eu = df1[df1['continent'] == 'Europe'].reset_index()
df1_NA = df1[df1['continent'] == 'North America'].reset_index()
df1_SA = df1[df1['continent'] == 'South America'].reset_index()
df1_AS = df1[df1['continent'] == 'Asia'].reset_index()
df1_AF = df1[df1['continent'] == 'Africa'].reset_index()

# %%
# %matplotlib widget
debut = 0
fin = 10000
plt.plot(df1_eu['new_cases_smoothed'][debut:fin])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib inline
debut = 0
fin = 20
plt.plot(df1_fr['date'][debut:fin])
