# %% [markdown]
# # ET3-MTX Contrôle Numpy 2024
#
# - Renommer le fichier en : ET3_MTX_2024_Nom_Prenom.ipynb
#
# ---

# %% [markdown]
# ## 1 : numpy vs Listes
# ----
#
# 1. Création des données :
#
#     - Crée une liste Python de 10 millions de nombres aléatoires compris entre 0 et 1.
#     - Crée un tableau Numpy de 10 millions de nombres aléatoires compris entre 0 et 1.
#
# 2. Calcul de la moyenne :
#
#     - Calcule la moyenne des éléments de la liste Python.
#     - Calcule la moyenne des éléments du tableau Numpy.
#
# 3. Mesure du temps d'exécution :
#
#     - Mesure le temps d'exécution pour le calcul de la moyenne avec la liste Python.
#     - Mesure le temps d'exécution pour le calcul de la moyenne avec le tableau Numpy.
#
# 4. Analyse des résultats :
#
#     - Compare les temps d'exécution pour déterminer quelle méthode est la plus rapide.
#
#
# Aide : pour avoir le temps d'execution on utilise :
#
# 1. import time
#     - start_time = time.time()
#     - run programme
#     - end_time = time.time()
#
#
# Conclusion :
#
#     - comparer les 2 méthodes pour le calcul

# %% [markdown]
# ## 2  : Slices dans Numpy
# ---
# Étapes :
#
# 1. Création des données :
#
# Crée un tableau Numpy 2D (matrice) de 10x10 rempli de nombres aléatoires compris entre 0 et 100.
#
# 2. Extraction et manipulation :
#
#     - Extrait la première colonne.
#     - Extrait la dernière ligne.
#     - Extrait un sous-tableau central de 4x4 à partir de la position (3,3).
#     - Double les valeurs du sous-tableau central.
#     - Remplace une sous-partie de la matrice originale par le sous-tableau central modifié.
#
# 3. Affichage des résultats :
#
# Affiche la matrice originale, la première colonne, la dernière ligne, le sous-tableau central, et la matrice finale modifiée.

# %% [markdown]
# ## 3 Création et Manipulation de Tableaux Numpy
# ---
# Étapes :
#
# 1. Création des tableaux :
#
#     - Crée un tableau 1D de 20 nombres aléatoires compris entre 0 et 50.
#     - Crée un tableau 2D de 5x4 rempli de nombres aléatoires compris entre 0 et 100.
#
# 2. Manipulations de base :
#
#     - Change la forme du tableau 1D en un tableau 2D de 4x5.
#     - Extrai les éléments des deuxième et troisième colonnes du tableau 2D.
#     - Calcule la somme des éléments de chaque ligne du tableau 2D.
#     - Trouve l'élément maximum et minimum du tableau 2D.
#
# 3. Manipulations avancées :
#
#     - Crée un masque pour extraire tous les éléments du tableau 2D qui sont supérieurs à 50.
#     - Remplace tous les éléments du tableau 2D qui sont inférieurs à 30 par 30.
#     - Ajoute une nouvelle colonne au tableau 2D initial rempli de zéros.
#
# 4. Affichage des résultats :
#
#     - Affiche les tableaux et les résultats de chaque étape.

# %% [markdown]
# ## 4 Exercice : Sélections Conditionnelles dans un Tableau Numpy
# ----
#
# Étapes :
#
# 1. Création des données :
#
#     - Crée un tableau Numpy 2D de 8x8 rempli de nombres aléatoires compris entre 0 et 100.
#
# 2. Sélections conditionnelles :
#
#     - Sélectionne tous les éléments du tableau qui sont pairs.
#     - Sélectionne tous les éléments du tableau qui sont supérieurs à 50.
#     - Sélectionne les éléments du tableau qui sont dans l'intervalle [20, 80].
#
# 2. Manipulations basées sur des conditions :
#
#     - Remplace tous les éléments pairs par leur double.
#     - Remplace tous les éléments supérieurs à 50 par 50.
#     - Remplace tous les éléments dans l'intervalle [20, 80] par -1.
#
# 3. Affichage des résultats :
#
#     - Affiche le tableau original.
#     - Affiche les sélections effectuées.
#     - Affiche le tableau après chaque manipulation conditionnelle.

# %% [markdown]
# ## 5 Exercice : Utilisation de numpy.where et des Filtres Classiques
# ---
#
# Étapes :
#
# 1. Création des données :
#
#     - Crée un tableau Numpy 2D de 10x10 rempli de nombres aléatoires compris entre 0 et 100.
#
# 2. Utilisation des filtres classiques :
#
#     - Sélectionne tous les éléments du tableau qui sont inférieurs à 50.
#     - Remplace tous les éléments inférieurs à 50 par 0.
#
# 3. Utilisation de numpy.where :
#
#     - Sélectionne tous les éléments du tableau qui sont inférieurs à 50 en utilisant numpy.where.
#     - Remplace tous les éléments inférieurs à 50 par 0 en utilisant numpy.where.
#
# Affichage des résultats :
#
#     - Affiche le tableau original.
#     - Affiche les résultats des sélections et remplacements effectués par les filtres classiques et numpy.where.

# %% [markdown]
# ## 6  Création et Manipulation de Matrices
# ------
# Objectif : Apprendre à créer des matrices de différentes façons et à effectuer des manipulations simples en utilisant Numpy.
#
# Étapes :
#
# 1. Création des matrices :
#
#     - Crée une matrice 3x3 de zéros.
#     - Crée une matrice 4x4 de uns.
#     - Crée une matrice 5x5 d'entiers aléatoires entre 10 et 50.
#     - Crée une matrice identité de taille 6x6.
#
# 2. Manipulations de base :
#
#     - Modifie la matrice 3x3 de zéros en une matrice où les éléments de la diagonale principale sont égaux à 1.
#     - Modifie la matrice 4x4 de uns en une matrice où tous les éléments sont multipliés par 2.
#     - Ajoute 10 à chaque élément de la matrice 5x5 d'entiers aléatoires.
#     - Change la matrice identité 6x6 pour que les éléments de la dernière colonne soient égaux à 5.
#
# 3. Affichage des résultats :
#
#     - Affiche chaque matrice après création et après chaque manipulation.

# %% [markdown]
# ## 7 Manipulation des Types de Données dans Numpy
# -------
#
# Étapes :
#
# 1. Création des tableaux :
#
#     - Crée un tableau Numpy 1D de 10 nombres aléatoires compris entre 0 et 100, avec le type de données int32.
#     - Crée un tableau Numpy 2D de 5x5 rempli de nombres aléatoires à virgule flottante compris entre 0 et 1, avec le type de données float64.
#
# 2. Manipulations de type :
#
#     - Convertis le tableau 1D en type float64.
#     - Convertis le tableau 2D en type int32.
#     - Crée un tableau Numpy 1D de 5 éléments contenant des nombres complexes.
#     - Convertis le tableau de nombres complexes en type float64 et observe ce qui se passe.
#
# 3. Calculs et conversions supplémentaires :
#
#     - Crée un tableau Numpy 1D de 10 nombres aléatoires compris entre 0 et 100, avec le type de données int64.
#     - Calcule la moyenne des éléments de ce tableau.
#     - Convertis le tableau en type float32 et recalculer la moyenne.
#     - Compare les résultats des moyennes.
#
# 4. Affichage des résultats :
#
#     - Affiche chaque tableau après création et après chaque manipulation de type.

# %% [markdown]
# ## 8 : Array : Calculs divers
# -----
# Etapes:
#
# Créer une matrice carrée entre 20 et 250  et de taille  12x12
#
# - Extraire tous les nombres impairs plus grands que 100
# - Extraires les multiples de 7
# - Extraire les élements supérieurs à 7
# - Extraire les éléments impairs, inférieurs à 120
# - remplacer les éléments supérieurs à 120 par leur valeur + 7
# - créer enfin un vecteur à partir de tous les éléments de la matrice.

# %% [markdown]
# ## 9 Matrice : calculs sur colonnes, lignes
# -------
#
# Etapes :
#
# Créer une matrice carrée de taille 12x12 de nombres entiers aléatoires compris entre 0 à 100
#
#     - Donnez le maximum pour chaque ligne
#     - Donnez la moyenne pour chaque Colonne
#     - La position du minimum pour chaque ligne
#     - Rendre la matrice plate (1 ligne)

# %% [markdown]
# ##  10 : filtrage sur matrice
# ---
# avec la matrice initiale de l'exercice 9
# passer un filtre de taille 2x2 sur la matrice et créer une nouvelle matrice qui va contenir :
# 1. les valeurs moyennes sur le filtre
# 2. le max
# 3. le min
#
# plot des resultats :
#
# - en utilisant matplotlib imshow.
# - import matplotlib.pyplot as plt
# - plt.imshow(matrice)
#
# idem avec filtre 3x3

# %% [markdown]
# # FIN
