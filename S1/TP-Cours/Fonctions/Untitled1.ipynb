# %%
def addition(val1, val2):
    val = val1 + val2 
    #print(val1 + val2)
    return val

def renvoie_liste(val1, val2):
    """
    donne les listes val1 et val2
    """
    return [val1, val2]

# %%
renvoie_liste
# Out:
# Signature: renvoie_liste(val1, val2)
# Docstring: donne les listes val1 et val2
# File:      /var/folders/q1/y9335yzs7txdys94p22s17f40000gq/T/ipykernel_23942/2290770808.py
# Type:      function

# %%
L1 = [2, 3, 5, 23]
L2 = [12, 23, 35]

def somme_listes(L1, L2):
    le1 = len(L1)
    le2 = len(L2)
    m = min(le1, le2)
    L = []
#    for ind, val1 in enumerate(L1):
    for ind in range(m):
        L.append(L1[ind]+L2[ind])
    return L
somme_listes(L1, L2)
# Out:
# [14, 26, 40]

# %%
for va1, va2 in zip(L1, L2):
    print(va1, va2)
# Out:
# 2 12
# 3 23
# 5 35

# %%
chaine = f'sdlkjdjkzh{1}oiidhkdh {1.22} dlkjdlkj{33}'
chaine
# Out:
# 'sdlkjdjkzh1oiidhkdh 1.22 dlkjdlkj33'

# %%
val_ret = addition([2, 3], [4, 5])
val_ret
# Out:
# [2, 3, 4, 5]

# %%
type(renvoie_liste(3, 4))
# Out:
# list

# %%
L1 = [2, 3, 4, 5]
def func(L):
    L.append(12)

# appel de la fonction
func(L1)
# print ...
L1
# Out:
# [2, 3, 4, 5, 12]

# %%
pwd
# Out:
# '/Users/guler/Lectures/python-teaching/S1/TP-Cours/Fonctions'

# %%
ls
# Out:
# Les fonctions et les fichiers.ipynb  data/
# Untitled.ipynb                       introducing_functions.ipynb
# Untitled1.ipynb                      more_functions.ipynb

# %%
f = open('data/horace.txt')
fich = f.read()
fich.split()
# Out:
# ['Approuvez',
#  'ma',
#  'faiblesse,',
#  'et',
#  'souffrez',
#  'ma',
#  'douleur,',
#  'Elle',
#  "n'est",
#  'que',
#  'trop',
#  'juste',
#  'en',
#  'un',
#  'si',
#  'grand',
#  'malheur',
#  ';',
#  'Si',
#  'près',
#  'de',
#  'voir',
#  'sur',
#  'soi',
#  'fondre',
#  'de',
#  'tels',
#  'orages,',
#  "L'ébranlement",
#  'sied',
#  'bien',
#  'aux',
#  'plus',
#  'fermes',
#  'courages,',
#  'Et',
#  "l'esprit",
#  'le',
#  'plus',
#  'mâle',
#  'et',
#  'le',
#  'moins',
#  'abattu',
#  'Ne',
#  'saurait',
#  'sans',
#  'désordre',
#  'exercer',
#  'sa',
#  'vertu.',
#  'Quoique',
#  'le',
#  'mien',
#  "s'étonne",
#  'à',
#  'ces',
#  'rudes',
#  'alarmes,',
#  'Le',
#  'trouble',
#  'de',
#  'mon',
#  'coeur',
#  'ne',
#  'peut',
#  'rien',
#  'sur',
#  'mes',
#  'larmes,',
#  'Et',
#  'parmi',
#  'les',
#  'soupirs',
#  "qu'il",
#  'pousse',
#  'vers',
#  'les',
#  'cieux,',
#  'Ma',
#  'constance',
#  'du',
#  'moins',
#  'règne',
#  'encore',
#  'sur',
#  'mes',
# ...
